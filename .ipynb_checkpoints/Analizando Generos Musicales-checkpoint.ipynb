# %%
import pandas as pd
import numpy as np
import os
os.chdir("C:/Users/Asus/Desktop/DATA SCIENCE/MAESTRIA/Data Mining/tp_data_mining")
data_path = "C:/Users/Asus/Desktop/DATA SCIENCE/MAESTRIA/Data Mining/tp_data_mining/data"

# %%
filename = "genres_by_artist_id.csv"

# %%
genres = pd.read_csv(data_path+"/"+filename, encoding='iso-8859-1')
genres = genres.dropna().reset_index(drop=True)
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    519 non-null    object
#  1   artist_name  519 non-null    object
#  2   genres       519 non-null    object
# dtypes: object(3)
# memory usage: 12.3+ KB

# %%
generos = ",".join(genres.genres.to_list()).split(",")

from collections import Counter
counter = Counter()
for gen in generos: 
    counter[gen] += 1

ocurrences = pd.DataFrame(counter.items(), columns=['genre', 'counts']).sort_values(by="counts", ascending=False).reset_index(drop=True)

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (5,25)
fig, ax = plt.subplots()

lowbound = 2
graphic = ocurrences[ocurrences.counts>lowbound]

genre = graphic.genre.to_numpy()
y_pos = np.arange(len(genre))
counts = graphic.counts

ax.barh(y_pos, counts)
ax.set_yticks(y_pos)
ax.set_yticklabels(genre)
ax.invert_yaxis()  # labels read top-to-bottom
# ax.set_ylabel('Quantity')
# ax.set_title('Most Common Words')

plt.show()

# %%
ocurrences["n_words"] = ocurrences.genre.apply(lambda x: len(x.split(" ")))
ocurrences["length"] = ocurrences.genre.apply(lambda x: len(x))
ocurrences.sort_values(by=["n_words","length"], ascending=[True, True])
# Out:
#                            genre  counts  n_words  length
# 0                            pop     164        1       3
# 2                            rap      88        1       3
# 10                           edm      43        1       3
# 19                           r&b      19        1       3
# 266                          emo       1        1       3
# ..                           ...     ...      ...     ...
# 98     canadian contemporary r&b       3        3      25
# 124           east coast hip hop       2        4      18
# 280          deep german hip hop       1        4      19
# 173       north carolina hip hop       2        4      22
# 122  italian underground hip hop       2        4      27
#
# [376 rows x 4 columns]

# %%
ocurrences[ocurrences.n_words==2].iloc[:50,:]
# Out:
#                    genre  counts  n_words  length
# 1              dance pop     116        2       9
# 3                pop rap      81        2       7
# 4          post-teen pop      72        2      13
# 7                hip hop      54        2       7
# 8            trap latino      50        2      11
# 11             pop dance      41        2       9
# 12        tropical house      37        2      14
# 15             latin pop      29        2       9
# 16           melodic rap      29        2      11
# 18        reggaeton flow      21        2      14
# 21         electro house      19        2      13
# 25                uk pop      15        2       6
# 26       adult standards      14        2      15
# 27           modern rock      12        2      11
# 28          classic rock      11        2      12
# 29              pop rock      11        2       8
# 31          gangster rap      11        2      12
# 32            vapor trap      10        2      10
# ...

# %%
genres[genres.genres.apply(lambda x: len(x.split(","))==1)]
# Out:
#                   artist_id        artist_name               genres
# 3    6fWVd57NKTalqvmjRd2t8Z           24kGoldn             cali rap
# 11   77qukKzmdI5BeMBR7WGUrN        Aaron Smith        chicago house
# 14   7vk5e3vY1uw9plTHJAMwjN        Alan Walker        electro house
# 21   2urF8dgLVfDjunO0pcHUEe       Alvaro Soler            latin pop
# 24   3jK9MiCrA42lLAdMGUZpwa     Anderson .Paak          escape room
# 30   1qQLhymHXFPtP5U8KNKsm6         Apache 207       german hip hop
# 45   2uFC1dAj5b0YU7vulKNZ0p        Banx & Ranx             basshall
# 46   35S20clEkkSNUo23ViaslZ           Band Aid     musical advocacy
# 52   7mnAzEmgquhrVtGob81SmO           Big Shaq           london rap
# 57   3yzRiNMZdTsSUgplcyYZ4i       Blanco Brown          country rap
# 61   54R6Y0I7jGUCveDTtI21nb           Boney M.              europop
# 73   5TYxZTjIPqKM8K8NuP9woO         C. Tangana       urbano espanol
# 80   4WZGDpNwrC0vNQyl9QzF7d        Capital Bra       german hip hop
# ...

# %%
generos = ['rap', 'pop', 'rock','urban','soul','alternative',"escape room","dancehall","punk",
           "reggae", "reggaeton", "latin", "funk","hip hop","k-pop","jazz","blues","celtic","salsa",
           "trap","house","r&b","edm","lounge","country","dance","folk", "swing","tropical",
           "indie","wave","emo","rockabilly","sertanejo","bachata","urbano","disco", "trance", "basshall",
           "a cappella","gqom", "musical advocacy","k-rap"]

# %%
regex = re.compile(r"\b("+"|".join(generos)+")\W")

# def select_one_genre(text): 
#     selected = re.findall(regex, x)[0]
#     if selected == []:
#         splitted = text.split(" "):
#         lista = []
#         for s in splitted: 
#             if s in generos: 
#                 lista.append(s)
#         return lista[0]
#     else:
#         return selected
# Out:
#   File "<ipython-input-157-a52a87453d2b>", line 6
#     splitted = text.split(" "):
#                               ^
# SyntaxError: invalid syntax

# %%
regex = re.compile(r"\b("+"|".join(generos)+")\W")
regex
# Out:
# re.compile(r'\b(rap|pop|rock|urban|soul|alternative|escape room|dancehall|punk|reggae|reggaeton|latin|funk|hip hop|k-pop|jazz|blues|celtic|salsa|trap|house|r&b|edm|lounge|country|dance|folk|swing|tropical|indie|wave|emo|rockabilly|sertanejo|bachata|urbano|disco|trance|basshall|a cappella|gqom|musical advocacy|k-rap)\W',
# re.UNICODE)

# %%
genres["selected"] = genres.genres.apply(lambda x: re.findall(regex, x))
genres
# Out:
#                   artist_id          artist_name  \
# 0    6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 1    17lzZA2AlOHwCwFALHttmp             2 Chainz
# 2    1URnnhqYAYcrqrcwql10ft            21 Savage
# 3    6fWVd57NKTalqvmjRd2t8Z             24kGoldn
# 4    5Rl15oVamLq7FbSb0NNBNy  5 Seconds of Summer
# ..                      ...                  ...
# 514  487N2T9nIPEHrlTZLL3SQs  Zé Neto & Cristiano
# 515  5CiGnKThu5ctn9pBxv7DGa         benny blanco
# 516  2cFrymmkijnjDg9SS92EPM            blackbear
# 517  19i93sA0D7yS9dYoVNBqAA          tha Supreme
# 518  0b1sIQumIAsNbqAoIClSpy               j-hope
#
#                                                 genres  \
# 0                               boy band,dance pop,pop
# 1    atl hip hop,gangster rap,hip hop,pop rap,rap,s...
# 2                                 atl hip hop,rap,trap
# 3                                             cali rap
# 4      boy band,dance pop,electropop,pop,post-teen pop
# ...

# %%
s = "cali rap"
re.findall("\b(rap|hip hop)\W", s)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-149-44be64460973> in <module>
#       1 s = "cali rap"
# ----> 2 re.findall("*\b(rap|hip hop)\W", s)
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# ...
