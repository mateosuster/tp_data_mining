# %%
import pandas as pd
import numpy as np
import re
import os
os.chdir("C:/Users/Asus/Desktop/DATA SCIENCE/MAESTRIA/Data Mining/tp_data_mining")
data_path = "C:/Users/Asus/Desktop/DATA SCIENCE/MAESTRIA/Data Mining/tp_data_mining/data"

# %%
filename = "genres_by_artist_id.csv"

# %%
genres = pd.read_csv(data_path+"/"+filename, encoding='iso-8859-1')
genres = genres.dropna().reset_index(drop=True)
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519 entries, 0 to 518
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    519 non-null    object
#  1   artist_name  519 non-null    object
#  2   genres       519 non-null    object
# dtypes: object(3)
# memory usage: 12.3+ KB

# %%
gens = np.unique(np.array(",".join(genres.genres).split(","))).tolist()

gens_dict = {}
for k,v in zip(gens,gens): 
    gens_dict[k]=v
    if "pop" in k:
        gens_dict[k]="pop"
    if "r&b" in k:
        gens_dict[k]="r&b"
    if "folk" in k: 
        gens_dict[k]="folk"
    if "rock" in k:
        gens_dict[k]="rock"
    if "rap" in k:
        gens_dict[k]="rap"
    if "k-pop" in k:
        gens_dict[k]="kpop"
    if "k-rap" in k: 
        gens_dict[k]="krap"
    if "hip hop" in k: 
        gens_dict[k]="hip hop"
    if "trap" in k:
        gens_dict[k]="trap"
    if "soul" in k:
        gens_dict[k]="soul"
    if "country" in k:
        gens_dict[k]="country"
    if "house" in k: 
        gens_dict[k] = "house"
    if "techno" in k: 
        gens_dict[k] = "techno"
    if "heavy metal" in k: 
        gens_dict[k] = "heavy metal"
    if "psych" in k: 
        gens_dict[k] = "psych"
    if "punk" in k: 
        gens_dict[k] = "punk"
    if "dance" in k:
        gens_dict[k] = "dance"
    if "funk" in k: 
        gens_dict[k] = "funk"
    if "indie" in k: 
        gens_dict[k] = "indie"
    if "metal" in k: 
        gens_dict[k] = "heavy metal"
    if "industrial" in k:
        gens_dict[k] = "industrial"
    if "talent show" in k: 
        gens_dict[k] = "talent show"
    if "wave" in k:
        gens_dict[k]="new wave"
    if "reggae" in k: 
        gens_dict[k]="reggae"
    if "reggaeton" in k: 
        gens_dict[k] = "reggaeton"
    if "salsa" in k: 
        gens_dict[k] = "salsa"
    if "urban" in k: 
        gens_dict[k] = "urban"
    if "urbano" in k: 
        gens_dict[k] = "urbano"
    if "sertanejo" in k: 
        gens_dict[k] = "sertanejo"
    if "romantic" in k: 
        gens_dict[k] = "romantic"
    if "edm" in k: 
        gens_dict[k] = "dance"
    if "electronic" in k: 
        gens_dict[k] = "electronic"
    if "alternative" in k: 
        gens_dict[k] = "alternative"
    if "alt" in k: 
        gens_dict[k] = "alternative"
    if "mellow" in k: 
        gens_dict[k] = "mellow"
    if "hardcore" in k: 
        gens_dict[k] = "hardcore"
    if "drill" in k: 
        gens_dict[k] = "drill"
    if "afro" in k: 
        gens_dict[k]="afro"

# %%
len(gens)
# Out:
# 376

# %%
len(np.unique(np.array([v for k,v in gens_dict.items()])))
# Out:
# 99

# %%
np.unique(np.array([v for k,v in gens_dict.items()]))
# Out:
# array(['a cappella', 'adult standards', 'afro', 'alternative', 'bachata',
#        'basshall', 'beatlesque', 'big band', 'big room', 'bmore',
#        'boy band', 'broadway', 'brostep', 'celtic', 'champeta', 'circuit',
#        'classic girl group', 'complextro', 'country', 'cowboy western',
#        'cumbia', 'dance', 'dark clubbing', 'disco', 'double drumming',
#        'downtempo', 'drill', 'dutch trance', 'easy listening',
#        'electro latino', 'electronic', 'emo', 'escape room', 'eurovision',
#        'folk', 'forro', 'francoton', 'funk', 'girl group', 'gqom',
#        'grime', 'guaracha', 'hardcore', 'heavy metal', 'hip hop',
#        'hollywood', 'house', 'indie', 'industrial',
#        'irish singer-songwriter', 'jazz blues', 'kpop', 'krap', 'laiko',
#        'latin', 'lounge', 'madchester', 'mellow', 'moombahton', 'motown',
#        'movie tunes', 'musical advocacy', 'neo-singer-songwriter',
#        'neue deutsche harte', 'new wave', 'ninja', 'pagode baiano',
#        'perreo', 'plugg', 'pop', 'post-disco', 'psych', 'punk',
#        'quiet storm', 'r&b', 'rap', 'reggaeton', 'rock', 'romantic',
#        'salsa', 'sertanejo', 'show tunes', 'singer-songwriter', 'soul',
#        'stomp and holler', 'swing', 'talent show', 'techno', 'torch song',
#        'trance', 'trap', 'tropical', 'uk americana',
#        'ukrainian classical', 'urban', 'urbano', 'vallenato',
#        'vocal jazz', 'yodeling'], dtype='<U23')

# %%
[k for k,v in gens_dict.items() if v == "rap"]
# Out:
# ['alabama rap',
#  'baton rouge rap',
#  'cali rap',
#  'chicago rap',
#  'christlicher rap',
#  'comedy rap',
#  'dfw rap',
#  'dirty south rap',
#  'dmv rap',
#  'dutch rap pop',
#  'emo rap',
#  'florida rap',
#  'frauenrap',
#  'gangster rap',
#  'german cloud rap',
#  'german underground rap',
#  'houston rap',
#  'london rap',
#  'melodic rap',
#  'meme rap',
#  'new orleans rap',
#  'nyc rap',
#  'philly rap',
#  'pittsburgh rap',
#  'pop rap',
#  'rap',
#  'rap conscient',
#  'rap dominicano',
#  'rap francais',
#  'rap latina',
#  'rap napoletano',
#  'rap sardegna',
#  'rap tunisien',
#  'rhode island rap',
#  'sad rap',
#  'toronto rap',
#  'viral rap',
#  'west coast rap']

# %%
def clean_genre(text):
    Split = text.split(",")
    for i in range(len(Split)): 
        Split[i] = gens_dict[Split[i]]
    return Split

def most_frequent(List):
    return max(set(List), key = List.count)

def select_genre(text):
    List = clean_genre(text)
    mf = most_frequent(List)
    return mf

# %%
genres['select_genre'] = genres.genres.apply(lambda x: select_genre(x))
genres
# Out:
#                   artist_id          artist_name  \
# 0    6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 1    17lzZA2AlOHwCwFALHttmp             2 Chainz
# 2    1URnnhqYAYcrqrcwql10ft            21 Savage
# 3    6fWVd57NKTalqvmjRd2t8Z             24kGoldn
# 4    5Rl15oVamLq7FbSb0NNBNy  5 Seconds of Summer
# ..                      ...                  ...
# 514  487N2T9nIPEHrlTZLL3SQs  Zé Neto & Cristiano
# 515  5CiGnKThu5ctn9pBxv7DGa         benny blanco
# 516  2cFrymmkijnjDg9SS92EPM            blackbear
# 517  19i93sA0D7yS9dYoVNBqAA          tha Supreme
# 518  0b1sIQumIAsNbqAoIClSpy               j-hope
#
#                                                 genres select_genre
# 0                               boy band,dance pop,pop          pop
# 1    atl hip hop,gangster rap,hip hop,pop rap,rap,s...      hip hop
# 2                                 atl hip hop,rap,trap      hip hop
# 3                                             cali rap          rap
# 4      boy band,dance pop,electropop,pop,post-teen pop          pop
# ..                                                 ...          ...
# 514    sertanejo,sertanejo pop,sertanejo universitario    sertanejo
# 515                             electropop,pop,pop rap          pop
# 516                             electropop,pop,pop rap          pop
# 517          italian hip hop,italian pop,trap italiana      hip hop
# 518                                        k-pop,k-rap         kpop
#
# [519 rows x 4 columns]

# %%
genres[['genres','select_genre']].to_records(index=False)
# Out:
# rec.array([('boy band,dance pop,pop', 'pop'),
#            ('atl hip hop,gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('atl hip hop,rap,trap', 'hip hop'), ('cali rap', 'rap'),
#            ('boy band,dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('alternative r&b,atl hip hop,hip hop,melodic rap,pop rap,r&b,rap,trap', 'rap'),
#            ('emo rap,rap', 'rap'),
#            ('melodic rap,pop rap,rap,trap', 'rap'),
#            ('hip hop,pop rap,rap,southern hip hop,trap,underground hip hop', 'hip hop'),
#            ('east coast hip hop,hip hop,rap,trap', 'hip hop'),
#            ('australian rock,hard rock,rock', 'rock'),
#            ('chicago house', 'house'),
#            ('alternative hip hop,conscious hip hop,escape room,hip hop,rap,southern hip hop,underground hip hop', 'hip hop'),
#            ('latin pop,latin talent show,spanish pop', 'pop'),
#            ('electro house', 'house'), ('alt z,electropop,pop', 'pop'),
#            ('canadian contemporary r&b,canadian pop,dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('dance pop,edm,electro house,pop,pop dance,progressive electro house,tropical house', 'house'),
#            ('latin,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('canadian hip hop,pop', 'hip hop'), ('latin pop', 'pop'),
#            ('dominican pop,latin,latin hip hop,rap dominicano,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('hip hop,pop rap,portland hip hop,rap,underground hip hop', 'hip hop'),
#            ('escape room', 'escape room'),
#            ('adult standards,brill building pop,easy listening,lounge,mellow gold,vocal jazz', 'adult standards'),
#            ('funk carioca,funk pop,pagode baiano,pop nacional', 'funk'),
#            ('dance pop,pop,pop dance,post-teen pop,tropical house,uk pop', 'pop'),
#            ('chill r&b,pop', 'r&b'),
#            ('latin,reggaeton,reggaeton flow,trap boricua,trap latino', 'reggaeton'),
#            ('german hip hop', 'hip hop'),
#            ('garage rock,modern rock,permanent wave,rock,sheffield indie', 'rock'),
#            ('classic soul,jazz blues,memphis soul,soul,southern soul', 'soul'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('pop rap,rhode island rap', 'rap'),
#            ('dutch trance,edm,pop dance,progressive house,trance', 'dance'),
#            ('dance pop,pop', 'pop'),
#            ('dance pop,edm,pop,pop dance', 'dance'),
#            ('canadian pop,candy pop,dance pop,pop,post-teen pop', 'pop'),
#            ('dance pop,edm,electro house,pop,pop dance,tropical house', 'dance'),
#            ('albanian hip hop,german hip hop', 'hip hop'),
#            ('k-pop,k-pop girl group', 'kpop'),
#            ('boy band,hip hop,rap', 'hip hop'),
#            ('k-pop,k-pop boy group', 'kpop'),
#            ('latin,reggaeton,trap latino', 'reggaeton'),
#            ('basshall', 'basshall'),
#            ('musical advocacy', 'musical advocacy'),
#            ('dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('dance pop,latin,latin pop,latin viral pop,pop,rap latina,reggaeton,trap latino', 'pop'),
#            ('dance pop,pop,post-teen pop,r&b', 'pop'),
#            ('detroit hip hop,hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('london rap', 'rap'), ('electropop,pop', 'pop'),
#            ('adult standards,easy listening,lounge', 'easy listening'),
#            ('argentine hip hop,pop venezolano,trap argentino,trap latino', 'trap'),
#            ('dance pop,pop,pop rap', 'pop'), ('country rap', 'country'),
#            ('memphis hip hop,rap,southern hip hop,tennessee hip hop,trap,vapor trap', 'hip hop'),
#            ('cali rap,trap', 'trap'),
#            ('cumbia,latin alternative,latin rock,pop electronico', 'alternative'),
#            ('europop', 'pop'),
#            ('german hip hop,hamburg hip hop', 'hip hop'),
#            ('adult standards,brill building pop,easy listening,lounge,rockabilly,vocal jazz', 'adult standards'),
#            ('contemporary country,country,country road,modern country rock', 'country'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('classic rock,heartland rock,mellow gold,permanent wave,rock,singer-songwriter', 'rock'),
#            ('dance pop,pop', 'pop'),
#            ('latin,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('pop,pop rap', 'pop'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('adult standards,american folk revival', 'adult standards'),
#            ('deep german hip hop,german hip hop', 'hip hop'),
#            ('urbano espanol', 'urbano'),
#            ('boy band,latin,latin pop,reggaeton', 'reggaeton'),
#            ('chicago rap,melodic rap,rap,trap,vapor trap', 'rap'),
#            ('indie cafe pop,pop', 'pop'),
#            ('dance pop,edm,electro house,house,pop,progressive house,uk dance', 'house'),
#            ('dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('colombian pop,reggaeton colombiano', 'pop'),
#            ('german hip hop', 'hip hop'),
#            ('italian hip hop,trap italiana', 'hip hop'),
#            ('dance pop,pop,pop rap,rap', 'rap'),
#            ('champeta,colombian pop,latin,latin pop,tropical,vallenato', 'pop'),
#            ('edm,electro house,electronic trap,pop rap,trap', 'dance'),
#            ('dance pop,downtempo,pop,post-teen pop,shiver pop', 'pop'),
#            ('latin,perreo,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('chicago rap,conscious hip hop,hip hop,pop rap,rap', 'rap'),
#            ('art pop,candy pop,dance pop,electropop,hyperpop,metropopolis,pop,post-teen pop,uk pop', 'pop'),
#            ('dance pop,pop,post-teen pop,viral pop', 'pop'),
#            ('dance pop,edm,electro house,electropop,pop,pop dance,pop edm,post-teen pop,tropical house', 'dance'),
#            ('atl hip hop,hip hop,pop rap,rap', 'hip hop'),
#            ('colombian hip hop,colombian pop,latin,latin alternative,latin pop,reggaeton colombiano,salsa choke', 'pop'),
#            ('dance pop,pop,pop rap,r&b,rap', 'rap'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('art rock,blues rock,classic rock,classic uk pop,mellow gold,soft rock,sophisti-pop', 'rock'),
#            ('blues rock,classic rock,rock,rock-and-roll,rockabilly,soul', 'rock'),
#            ('dance pop,edm,pop,pop dance,post-teen pop,tropical house,uk dance,uk funky', 'dance'),
#            ('permanent wave,pop', 'new wave'),
#            ('dmv rap,hip hop,pop rap,rap,trap,underground hip hop,vapor trap', 'rap'),
#            ('latin,latin hip hop,perreo,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('canadian pop,dance pop', 'pop'),
#            ('hip hop,miami hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('dance pop,edm,electronic trap,pop,pop dance,pop rap', 'dance'),
#            ('north carolina hip hop,rap', 'hip hop'),
#            ('latin,latin hip hop,reggaeton,trap latino', 'hip hop'),
#            ('brega funk,funk carioca', 'funk'),
#            ('latin,r&b en espanol,reggaeton,trap latino', 'r&b'),
#            ('contemporary country,country,pop', 'country'),
#            ('latin,latin pop,pop venezolano,reggaeton,trap latino', 'pop'),
#            ('brill building pop', 'pop'),
#            ('album rock,classic rock,mellow gold,rock,soft rock,yacht rock', 'rock'),
#            ('big room,dance pop,edm,pop,pop dance', 'dance'),
#            ('alt z,dance pop,edm,electropop,indie poptimism,pop,pop dance,post-teen pop,tropical house,uk pop', 'pop'),
#            ('circuit,guaracha,perreo', 'perreo'),
#            ('australian pop,indie cafe pop,pop,pop rock,post-teen pop', 'pop'),
#            ('adult standards,easy listening,lounge,vocal jazz', 'easy listening'),
#            ('dance pop,pop,post-teen pop', 'pop'), ('israeli pop', 'pop'),
#            ('folk-pop,irish pop,pop', 'pop'),
#            ('belgian dance,belgian edm,big room,edm,electro house,pop dance,progressive electro house,tropical house', 'dance'),
#            ('bmore,dance pop,edm,moombahton,ninja,pop,pop dance,tropical house', 'dance'),
#            ('chilean hardcore', 'hardcore'), ('dance pop,pop', 'pop'),
#            ('alternative pop rock,pop,pop rap', 'alternative'),
#            ('trap latino,urbano espanol', 'urbano'), ('rap,trap', 'trap'),
#            ('chicago soul,classic soul,funk,motown,neo soul,quiet storm,soul', 'soul'),
#            ('canadian hip hop,canadian pop,hip hop,pop rap,rap,toronto rap', 'rap'),
#            ('hip hop,rap,underground hip hop', 'hip hop'),
#            ('dance pop,pop,uk pop', 'pop'),
#            ('argentine hip hop,trap argentino,trap latino,trap triste', 'trap'),
#            ('dutch pop', 'pop'),
#            ('edm,electro house,pop dance,tropical house', 'house'),
#            ('latin,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('k-pop,k-pop boy group', 'kpop'),
#            ('disco,funk,jazz funk,motown,quiet storm,soul', 'funk'),
#            ('adult standards,lounge,torch song,vocal jazz', 'adult standards'),
#            ('pop,uk pop', 'pop'), ('eurovision,greek pop,laiko', 'laiko'),
#            ('adult standards,jazz blues,swing,vocal jazz', 'adult standards'),
#            ('dance pop,pop,pop r&b,pop rap,post-teen pop,r&b,uk contemporary r&b,urban contemporary', 'r&b'),
#            ('dance pop,edm,electropop,indietronica,metropopolis,pop,post-teen pop,uk pop', 'pop'),
#            ('glam rock,mellow gold,piano rock', 'rock'),
#            ('rock-and-roll,rockabilly', 'rock'),
#            ('detroit hip hop,hip hop,rap', 'hip hop'),
#            ('dance pop,latin,latin pop,mexican pop,pop', 'pop'),
#            ('alt z,dance pop,electropop,indie cafe pop,indie poptimism,pop,post-teen pop', 'pop'),
#            ('chicago rap,drill,rap,southern hip hop,trap,underground hip hop,vapor trap', 'hip hop'),
#            ('german hip hop', 'hip hop'),
#            ('funk carioca,sertanejo,sertanejo pop,sertanejo universitario', 'sertanejo'),
#            ('german hip hop', 'hip hop'),
#            ('melodic rap,pop rap,rap,trap,vapor trap', 'rap'),
#            ('baroque pop,pop,uk alternative pop', 'pop'),
#            ('contemporary country,country,country pop,country road,modern country rock', 'country'),
#            ('alternative r&b,hip hop,lgbtq+ hip hop,neo soul,pop', 'hip hop'),
#            ('adult standards,easy listening,lounge', 'easy listening'),
#            ('gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('dutch hip hop,dutch pop,dutch rap pop', 'hip hop'),
#            ('atl hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('hip hop,indie pop rap,oakland hip hop,pop rap,rap', 'hip hop'),
#            ('pop rap,trap soul', 'soul'),
#            ('forro,sertanejo pop', 'sertanejo'),
#            ('dance pop,edm,electro house,pop,pop dance,tropical house', 'dance'),
#            ('edm,lithuanian edm,lithuanian electronic,pop dance', 'dance'),
#            ('italian hip hop', 'hip hop'),
#            ('adult standards,cowboy western,oklahoma country,traditional country,yodeling', 'country'),
#            ('folk-pop,modern rock,neo-singer-songwriter,pop,pop rock', 'rock'),
#            ('dark clubbing,destroy techno', 'techno'),
#            ('italian hip hop,italian pop,milan indie,rap tunisien', 'hip hop'),
#            ('alternative hip hop', 'alternative'),
#            ('francoton,french hip hop,pop urbaine,rap francais', 'hip hop'),
#            ('dance pop,edm,electro house,pop,pop dance,tropical house', 'dance'),
#            ('latin,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('atl hip hop,dirty south rap,gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('atl hip hop,hip hop,melodic rap,rap,trap', 'hip hop'),
#            ('dance pop,hip pop,pop,pop rock,post-teen pop,urban contemporary', 'pop'),
#            ('alternative r&b,dance pop,pop,r&b', 'pop'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('dance pop,electropop,etherpop,indie poptimism,pop,post-teen pop', 'pop'),
#            ('pop,post-teen pop', 'pop'),
#            ('sertanejo pop,sertanejo universitario', 'sertanejo'),
#            ('irish singer-songwriter,modern rock,pop', 'rock'),
#            ('hollywood,show tunes', 'hollywood'),
#            ('hip hop,melodic rap,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('hollywood,show tunes', 'hollywood'),
#            ('modern rock,pop,rock', 'rock'), ('pop rap,rap,trap', 'rap'),
#            ('italian adult pop,italian pop', 'pop'),
#            ('latin,reggaeton,reggaeton colombiano,trap latino', 'reggaeton'),
#            ('conscious hip hop,north carolina hip hop,rap', 'hip hop'),
#            ('k-pop', 'kpop'),
#            ('alt z,canadian contemporary r&b,indie cafe pop,pop,post-teen pop', 'pop'),
#            ('pop,post-teen pop,talent show,uk pop', 'pop'),
#            ('indie soul,uk alternative pop', 'alternative'),
#            ('dance pop,pop,pop rap,post-teen pop', 'pop'),
#            ('acoustic pop,neo mellow,pop,pop rock', 'pop'),
#            ('dance pop,edm,electro house,house,pop,pop dance,pop rap,post-teen pop,tropical house,uk dance', 'dance'),
#            ('conscious hip hop,gangster rap,hip hop,pop rap,rap,southern hip hop,trap,underground hip hop', 'hip hop'),
#            ('electropop,pop,post-teen pop', 'pop'),
#            ('dance pop,pop,pop dance,post-teen pop,tropical house,uk pop', 'pop'),
#            ('latin,latin arena pop,latin pop,mexican pop,pop', 'pop'),
#            ('latin,reggaeton,trap latino', 'reggaeton'),
#            ('latin,latin hip hop,latin pop,panamanian pop,pop reggaeton,reggaeton,trap latino', 'pop'),
#            ('neo soul,pop,pop soul,r&b,urban contemporary', 'soul'),
#            ('album rock,art rock,beatlesque,classic rock,folk rock,mellow gold,rock', 'rock'),
#            ('neo mellow,pop,pop rock,singer-songwriter', 'singer-songwriter'),
#            ('alternative r&b,viral pop', 'alternative'),
#            ('dance pop,edm,pop,pop dance,tropical house,uk dance', 'dance'),
#            ('boy band,dance pop,pop,pop rock,post-teen pop', 'pop'),
#            ('pop,r&b,uk contemporary r&b', 'r&b'),
#            ('latin pop,puerto rican pop', 'pop'),
#            ('album rock,classic rock,hard rock,mellow gold,rock,soft rock', 'rock'),
#            ('boston hip hop,hip hop,pop rap,rap', 'hip hop'),
#            ('dance pop,electro latino,latin,latin pop,reggaeton', 'dance'),
#            ('adult standards,hollywood,lounge,torch song,vocal jazz', 'adult standards'),
#            ('chicago rap,melodic rap', 'rap'),
#            ('frauenrap,german hip hop,german pop', 'hip hop'),
#            ('alt z,dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('canadian pop,pop,post-teen pop', 'pop'),
#            ('latin,reggaeton,trap latino', 'reggaeton'),
#            ('dance pop,pop', 'pop'), ('k-pop girl group', 'kpop'),
#            ('latin,reggaeton,reggaeton colombiano,trap latino', 'reggaeton'),
#            ('german drill,german hip hop', 'hip hop'),
#            ('argentine hip hop,trap argentino,trap latino,trap triste', 'trap'),
#            ('hip hop,rap,underground hip hop', 'hip hop'),
#            ('uk hip hop', 'hip hop'), ('pop,pop rap,rap', 'rap'),
#            ('german drill,german hip hop,german underground rap', 'hip hop'),
#            ('chicago rap,rap', 'rap'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('broadway,hollywood,show tunes', 'hollywood'),
#            ('dance pop,pop,pop rap,post-teen pop,r&b', 'pop'),
#            ('dance pop,neo mellow,pop,pop rock,post-teen pop,talent show', 'pop'),
#            ('conscious hip hop,hip hop,rap,west coast rap', 'hip hop'),
#            ('latin,latin hip hop,reggaeton,reggaeton colombiano,reggaeton flow,trap latino', 'reggaeton'),
#            ('pop', 'pop'), ('sad rap', 'rap'),
#            ('alt z,dance pop,electropop,indie pop,indie poptimism,nyc pop,pop,post-teen pop', 'pop'),
#            ('german hip hop,german pop,hamburg hip hop', 'hip hop'),
#            ('florida rap,hip hop,melodic rap,miami hip hop,rap,southern hip hop,trap', 'hip hop'),
#            ('christlicher rap,german hip hop', 'hip hop'),
#            ('dutch house,dutch pop', 'pop'),
#            ('edm,pop,pop dance,tropical house', 'dance'),
#            ('australian dance,australian pop,dance pop,electropop,eurodance,europop,new wave pop,pop', 'pop'),
#            ('la pop,pop,post-teen pop', 'pop'),
#            ('indie poptimism,pop', 'pop'),
#            ('dance pop,pop,post-teen pop', 'pop'), ('art pop,pop', 'pop'),
#            ('dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('latin pop,viral pop', 'pop'),
#            ('british soul,dance pop,europop,pop,post-teen pop,talent show', 'pop'),
#            ('bachata,latin', 'bachata'), ('pop,uk pop', 'pop'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('atl hip hop,atl trap,rap,trap', 'trap'),
#            ('comedy rap,pop rap,rap', 'rap'),
#            ('melodic rap,rap,rap conscient,trap,vapor trap', 'rap'),
#            ('lgbtq+ hip hop,pop rap', 'hip hop'),
#            ('emo rap,lgbtq+ hip hop', 'hip hop'),
#            ('emo rap,miami hip hop,rap,trap', 'rap'),
#            ('melodic rap,pop rap,rap,trap', 'rap'),
#            ('melodic rap,rap,trap', 'rap'),
#            ('brooklyn drill,melodic rap,nyc rap', 'rap'),
#            ('melodic rap,philly rap,rap,trap', 'rap'),
#            ('hip hop,new orleans rap,pop rap,rap,trap', 'rap'),
#            ('emo rap,underground hip hop', 'hip hop'),
#            ('atl hip hop,hip hop,melodic rap,rap,trap,underground hip hop', 'hip hop'),
#            ('dance pop,girl group,pop,post-teen pop,talent show,uk pop', 'pop'),
#            ('dance pop,escape room,minnesota hip hop,pop,pop rap,post-teen pop,trap queen', 'pop'),
#            ('conscious hip hop,dmv rap,hip hop,pop rap,rap', 'rap'),
#            ('indie folk,indie pop,stomp and holler', 'indie'),
#            ('frauenrap,german hip hop,kosovan pop,romanian pop', 'pop'),
#            ('deep talent show,hollywood,movie tunes', 'hollywood'),
#            ('dance pop,edm,electro house,pop,pop dance,pop edm,tropical house', 'dance'),
#            ('edm,electropop,indie poptimism,pop,tropical house', 'pop'),
#            ('pop,post-teen pop', 'pop'),
#            ('italian hip hop,rap napoletano', 'hip hop'),
#            ('latin,latin pop,puerto rican pop', 'pop'),
#            ('danish pop,pop,scandipop', 'pop'),
#            ('latin,latin pop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('italian hip hop,trap italiana', 'hip hop'),
#            ('dance pop,electropop,pop,pop rap,post-teen pop,viral pop', 'pop'),
#            ('funk carioca,funk paulista', 'funk'),
#            ('funk 150 bpm,funk carioca', 'funk'),
#            ('funk bh,funk carioca,funk ostentacao', 'funk'),
#            ('brega funk,funk carioca', 'funk'),
#            ('funk carioca,funk consciente,funk ostentacao,funk paulista', 'funk'),
#            ('dance pop,edm,pop dance,pop house,tropical house', 'dance'),
#            ('dance pop,edm,pop,pop dance,post-teen pop,tropical house,uk pop', 'pop'),
#            ('hip hop,pittsburgh rap,rap', 'rap'),
#            ('ohio hip hop,pop rap', 'hip hop'),
#            ('pop rap,seattle hip hop', 'hip hop'),
#            ('alt z,dance pop,electropop,pop,post-teen pop', 'pop'),
#            ('alt z,pop,post-teen pop,social media pop', 'pop'),
#            ('italian pop', 'pop'),
#            ('dance pop,edm,electro house,moombahton,pop,pop dance,pop rap', 'dance'),
#            ('latin,reggaeton,reggaeton colombiano', 'reggaeton'),
#            ('reggaeton flow', 'reggaeton'),
#            ('colombian pop,latin,reggaeton,reggaeton colombiano,trap latino', 'reggaeton'),
#            ('latin,latin pop,modern salsa,salsa,tropical', 'salsa'),
#            ('contemporary country,country,pop,texas country', 'country'),
#            ('dance pop,pop,r&b,urban contemporary', 'pop'),
#            ('dance pop,pop', 'pop'), ('pop,pop rock', 'rock'),
#            ('italian hip hop,italian pop,italian underground hip hop,rap napoletano', 'hip hop'),
#            ('brostep,edm,pop,pop dance,progressive electro house', 'dance'),
#            ('dance pop,dutch edm,edm,pop,pop dance,progressive house,tropical house', 'dance'),
#            ('sertanejo,sertanejo pop', 'sertanejo'),
#            ('contemporary country,country', 'country'),
#            ('pop nacional,sertanejo pop,sertanejo universitario', 'sertanejo'),
#            ('talent show', 'talent show'),
#            ('latin,latin pop,pop venezolano,reggaeton,trap latino', 'pop'),
#            ('hip hop,philly rap,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('houston rap,pop,pop rap,trap queen', 'rap'),
#            ('dance pop,hip pop,pop,post-teen pop', 'pop'),
#            ('hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('adult standards,canadian pop,jazz pop,lounge', 'pop'),
#            ('pop,r&b,soul', 'soul'),
#            ('atl hip hop,pop rap,rap,trap', 'rap'),
#            ('dance pop,pop,r&b,urban contemporary', 'pop'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('cali rap,sacramento hip hop,trap', 'hip hop'),
#            ('modern folk rock,modern rock,stomp and holler,uk americana', 'rock'),
#            ('cali rap,hip hop,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('trap latino', 'trap'),
#            ('post-romantic era,ukrainian classical', 'ukrainian classical'),
#            ('forro,sertanejo pop', 'sertanejo'),
#            ('hip hop,virginia hip hop', 'hip hop'),
#            ('canadian hip hop,canadian trap,hip hop,melodic rap,pop rap,rap,toronto rap,trap', 'rap'),
#            ('hip hop,pop rap,rap', 'rap'), ('memphis hip hop', 'hip hop'),
#            ('dance pop,edm,electro house,electropop,pop,pop dance,pop edm,post-teen pop,tropical house', 'dance'),
#            ('dominican pop,latin,latin pop,pop reggaeton,pop venezolano,reggaeton,trap latino', 'pop'),
#            ('vapor pop', 'pop'),
#            ('conscious hip hop,east coast hip hop,gangster rap,hardcore hip hop,hip hop,queens hip hop,rap', 'hip hop'),
#            ('adult standards,lounge,soul,vocal jazz', 'adult standards'),
#            ('latin,latin pop,rap latina,reggaeton,trap latino', 'trap'),
#            ('french hip hop,pop urbaine,rap conscient', 'hip hop'),
#            ('eurovision,israeli pop', 'pop'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('dance pop,pop,post-teen pop,viral pop', 'pop'),
#            ('dance pop,hip pop,pop,pop rap,post-teen pop,queens hip hop', 'pop'),
#            ('latin,latin hip hop,reggaeton,trap latino', 'hip hop'),
#            ('german hip hop,swedish hip hop', 'hip hop'),
#            ('french hip hop,pop urbaine', 'hip hop'),
#            ('latin,reggaeton,trap latino', 'reggaeton'),
#            ('conscious hip hop,gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('alt z,dance pop,pop,post-teen pop', 'pop'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('turkish hip hop,turkish trap,turkish trap pop', 'trap'),
#            ('dance pop,pop,post-teen pop,r&b', 'pop'),
#            ('beatlesque,britpop,madchester,permanent wave,rock', 'madchester'),
#            ('atl hip hop,hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('flamenco urbano,urbano espanol', 'urbano'),
#            ('dance pop,piano rock,pop,pop rock', 'rock'),
#            ('latin,puerto rican pop,reggaeton,trap latino', 'reggaeton'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('pop,pop rap,r&b,rap,toronto rap,trap,urban contemporary', 'rap'),
#            ('french hip hop,pop urbaine', 'hip hop'),
#            ('latin pop,reggaeton chileno,trap chileno,trap latino', 'trap'),
#            ('baroque pop,emo,modern rock', 'rock'),
#            ('folk-pop,neo mellow,pop', 'kpop'),
#            ('album rock,art rock,beatlesque,classic rock,mellow gold,rock,soft rock', 'rock'),
#            ('argentine hip hop,trap argentino,trap latino', 'trap'),
#            ('latin,latin pop,puerto rican pop', 'pop'),
#            ('a cappella', 'a cappella'),
#            ('adult standards,brill building pop,easy listening,lounge,vocal jazz', 'adult standards'),
#            ('indie cafe pop', 'indie'), ('pop rap', 'rap'),
#            ('colombian pop,latin,latin pop,reggaeton,reggaeton colombiano,trap latino', 'reggaeton'),
#            ('atl hip hop,plugg,rap,trap', 'hip hop'),
#            ('chicago rap', 'rap'), ('pop r&b', 'r&b'),
#            ('indie rock,modern alternative rock,modern rock,rock', 'rock'),
#            ('dfw rap,melodic rap,rap', 'rap'),
#            ('bachata,latin,latin hip hop,latin pop', 'hip hop'),
#            ('alternative hip hop,gangster rap,hip hop,pop rap,rap,southern hip hop,trap,underground hip hop,virginia hip hop', 'hip hop'),
#            ('hip hop,melodic rap,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('atl hip hop,hip hop,melodic rap,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('classic rock,glam rock,rock', 'rock'),
#            ('dance pop,dutch house,edm,electro house,pop,pop dance,progressive electro house,slap house,tropical house', 'house'),
#            ('german hip hop', 'hip hop'), ('r&b en espanol', 'r&b'),
#            ('hip hop,melodic rap,mississippi hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('alternative metal,german metal,industrial,industrial metal,industrial rock,neue deutsche harte,nu metal', 'industrial'),
#            ('afroswing,london rap,uk hip hop', 'hip hop'),
#            ('puerto rican pop,trap latino', 'pop'),
#            ('disco,funk,post-disco,quiet storm', 'post-disco'),
#            ('k-pop,k-pop girl group', 'kpop'),
#            ('dance pop,edm,pop dance,pop edm,slap house,tropical house', 'dance'),
#            ('latin,latin arena pop,latin pop,mexican pop', 'pop'),
#            ('venezuelan hip hop', 'hip hop'),
#            ('turkish hip hop,turkish trap pop', 'hip hop'),
#            ('latin,reggaeton,trap latino', 'reggaeton'),
#            ('atl hip hop,hip hop,melodic rap,plugg,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('dirty south rap,gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('australian pop,dance pop,edm,electropop,pop,pop rap,post-teen pop,tropical house,uk pop', 'pop'),
#            ('dance pop,house,pop dance,tropical house,uk dance', 'dance'),
#            ('dance pop,deep euro house,deep house,edm,german dance,pop,pop dance,tropical house', 'dance'),
#            ('melodic rap,rap,trap', 'rap'), ('bachata,latin', 'bachata'),
#            ('dance pop,edm,house,pop,pop dance,tropical house,uk dance,uk funky', 'dance'),
#            ('hawaiian hip hop,pop rap,rap', 'rap'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('melodic rap,pop rap,rap,slap house', 'rap'),
#            ('electropop,pop', 'pop'),
#            ('frauenrap,german hip hop,german pop', 'hip hop'),
#            ('cali rap,trap,vapor trap', 'trap'),
#            ('pop,pop rap,r&b', 'r&b'),
#            ('alt z,dance pop,electropop,pop,post-teen pop,viral pop', 'pop'),
#            ('italian hip hop,italian underground hip hop,rap sardegna', 'hip hop'),
#            ('dance pop,edm,electro house,pop,pop dance,pop edm,tropical house', 'dance'),
#            ('dance pop,pop,post-teen pop,uk pop', 'pop'),
#            ('german hip hop', 'hip hop'),
#            ('cali rap,dance pop,pop,pop rap,trap queen', 'rap'),
#            ('gangster rap,hip hop,pop rap,rap,southern hip hop,trap,underground hip hop', 'hip hop'),
#            ('dance pop,dancehall,pop rap', 'dance'),
#            ('colombian pop,latin,reggaeton,reggaeton colombiano', 'reggaeton'),
#            ('latin,panamanian pop,reggaeton,trap latino', 'reggaeton'),
#            ('dance pop,edm,electro house,norwegian pop,pop,pop dance,pop edm,swedish pop,tropical house', 'dance'),
#            ('dance pop,pop,post-teen pop', 'pop'),
#            ('italian hip hop,italian pop,trap italiana', 'hip hop'),
#            ('classic uk pop,new wave pop,rock-and-roll,rockabilly', 'rock'),
#            ('colombian pop,dance pop,latin,latin pop,pop', 'pop'),
#            ('canadian pop,dance pop,pop,post-teen pop,viral pop', 'pop'),
#            ('rap,trap,underground hip hop,vapor trap', 'trap'),
#            ('german hip hop', 'hip hop'),
#            ('australian dance,australian pop,pop', 'pop'),
#            ('german hip hop', 'hip hop'),
#            ('dance pop,edm,pop,pop dance,tropical house', 'dance'),
#            ('dance pop,edm,house,pop dance,tropical house', 'dance'),
#            ('miami hip hop,underground hip hop', 'hip hop'),
#            ('alternative metal,double drumming,nu metal,rap metal', 'heavy metal'),
#            ('dark trap,melodic rap,meme rap,miami hip hop,rap,southern hip hop,trap,underground hip hop,vapor trap', 'hip hop'),
#            ('pop rap', 'rap'),
#            ('dance pop,latin,latin pop,mexican pop,pop', 'pop'),
#            ('afrofuturism,alternative r&b,dance pop,escape room,hip pop,indie soul,neo soul,pop,r&b,urban contemporary', 'pop'),
#            ('big band,swing', 'big band'),
#            ('dance pop,edm,electro house,pop,pop dance,tropical house', 'dance'),
#            ('funk,indie r&b,motown,quiet storm,soul', 'quiet storm'),
#            ('grime,uk hip hop', 'hip hop'), ('german hip hop', 'hip hop'),
#            ('pop,r&b', 'r&b'), ('k-pop', 'kpop'),
#            ('melodic rap,trap', 'trap'),
#            ('latin pop,pop argentino', 'pop'),
#            ('k-pop,k-pop boy group', 'kpop'),
#            ('album rock,classic rock,mellow gold,rock,soft rock,yacht rock', 'rock'),
#            ('k-pop,k-pop girl group', 'kpop'),
#            ('latin,latin hip hop,latin pop,pop reggaeton,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('atl hip hop,rap,southern hip hop,trap', 'hip hop'),
#            ('australian psych,neo-psychedelic', 'psych'),
#            ('pop,post-teen pop', 'pop'),
#            ('detroit hip hop,detroit trap,hip hop,rap,southern hip hop,trap', 'hip hop'),
#            ('dance pop,latin,latin pop,mexican pop', 'pop'),
#            ('modern alternative rock,modern rock,pop,rock', 'rock'),
#            ('baroque pop,brill building pop,classic rock,folk rock,psychedelic rock,rock,sunshine pop', 'rock'),
#            ('dance pop,pop,pop rap,r&b,urban contemporary', 'dance'),
#            ('dance pop,edm,electropop,pop,pop dance,tropical house', 'dance'),
#            ('irish rock,pop rock', 'rock'), ('motown,soul', 'motown'),
#            ('dance rock,modern rock,permanent wave,rock', 'rock'),
#            ('celtic,celtic punk,celtic rock,folk punk,irish folk,punk', 'punk'),
#            ('album rock,art rock,classic rock,mellow gold,new wave,permanent wave,rock,soft rock', 'rock'),
#            ('brill building pop,classic girl group,motown,soul', 'motown'),
#            ('reggaeton flow,trap brasileiro', 'reggaeton'),
#            ('canadian contemporary r&b,canadian pop,pop', 'pop'),
#            ('contemporary country,country,country road', 'country'),
#            ('big room,brostep,dance pop,dutch edm,edm,house,pop dance,slap house,trance,tropical house', 'dance'),
#            ('indie anthem-folk,indie cafe pop,modern rock,pop,uk pop', 'pop'),
#            ('australian pop,pop', 'pop'),
#            ('adult standards,easy listening,lounge,vocal jazz', 'easy listening'),
#            ('canadian hip hop,canadian trap,melodic rap,pop rap,r&b,rap,toronto rap,trap', 'rap'),
#            ('dance pop,neo mellow,pop,pop rock', 'pop'),
#            ('rap,slap house', 'house'),
#            ('alternative r&b,melodic rap,pop rap', 'rap'),
#            ('melodic rap,rap,trap', 'rap'),
#            ('afrofuturismo brasileiro,bass trap,electronic trap,funk carioca,pop nacional', 'trap'),
#            ('australian pop,dance pop,electropop,pop,post-teen pop,viral pop', 'pop'),
#            ('modern rock,rock', 'rock'), ('k-rap', 'krap'),
#            ('hip hop,pop,pop rap,r&b,southern hip hop,trap,trap soul', 'hip hop'),
#            ('dance pop,hip hop,pop rap,rap,southern hip hop,trap', 'hip hop'),
#            ('hip hop,rap', 'hip hop'),
#            ('german cloud rap,german hip hop', 'hip hop'),
#            ('italian adult pop,italian pop', 'pop'),
#            ('albanian hip hop,german drill,german hip hop', 'hip hop'),
#            ('conscious hip hop,escape room,hip hop,rap,underground hip hop', 'hip hop'),
#            ('argentine indie,trap argentino', 'trap'),
#            ('disco,europop,new romantic,new wave,new wave pop,soft rock,synthpop', 'pop'),
#            ('boy band,dance pop,pop,post-teen pop,teen pop', 'pop'),
#            ('latin,latin hip hop,reggaeton,trap latino', 'hip hop'),
#            ('electro latino,latin,latin hip hop,reggaeton,trap latino', 'hip hop'),
#            ('hip hop,pittsburgh rap,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('colombian pop,latin,reggaeton,trap latino', 'reggaeton'),
#            ('emo rap,miami hip hop', 'hip hop'), ('pop rap', 'rap'),
#            ('alabama rap,rap,trap,vapor trap,viral rap', 'rap'),
#            ('cali rap,gangster rap,hip hop,pop rap,rap,southern hip hop,trap', 'rap'),
#            ('melodic rap,trap', 'trap'),
#            ('british indie rock,modern rock,pop,rock', 'rock'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('dance pop,electropop,gauze pop,pop,post-teen pop,tropical house', 'pop'),
#            ('atl hip hop,atl trap,gangster rap,hip hop,melodic rap,pop rap,rap,trap', 'rap'),
#            ('baton rouge rap,trap', 'trap'),
#            ('dance pop,pop,post-teen pop,uk pop', 'pop'),
#            ('dance pop,hollywood,pop,post-teen pop,show tunes', 'pop'),
#            ('gqom', 'gqom'),
#            ('dance pop,edm,electropop,pop,pop dance,post-teen pop,scandipop,swedish electropop,swedish pop,tropical house', 'pop'),
#            ('complextro,dance pop,edm,electro house,electropop,german techno,pop,pop dance,post-teen pop,tropical house', 'dance'),
#            ('latin,latin hip hop,reggaeton,reggaeton flow,trap latino', 'reggaeton'),
#            ('sertanejo,sertanejo pop,sertanejo universitario', 'sertanejo'),
#            ('electropop,pop,pop rap', 'pop'),
#            ('electropop,pop,pop rap', 'pop'),
#            ('italian hip hop,italian pop,trap italiana', 'hip hop'),
#            ('k-pop,k-rap', 'kpop')],
#           dtype=[('genres', 'O'), ('select_genre', 'O')])

# %%
selected = genres[["artist_id","artist_name","select_genre"]]
selected.columns = ["artist_id","artist_name","selected_genre"]
selected.to_csv("data/selected_genres_by_id.csv", index=False, encoding='iso-8859-1')

# %%
generos = ",".join(selected.selected_genre.to_list()).split(",")

from collections import Counter
counter = Counter()
for gen in generos: 
    counter[gen] += 1

ocurrences = pd.DataFrame(counter.items(), columns=['genre', 'counts']).sort_values(by="counts", ascending=False).reset_index(drop=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

plt.rcParams['figure.figsize'] = (5,25)
fig, ax = plt.subplots()

lowbound = 2
graphic = ocurrences[ocurrences.counts>lowbound].reset_index(drop=True)

sns.set_color_codes("muted")
sns.barplot(x="counts", y="genre", data=graphic,
            label="Counts by Genre", color="b")

plt.show()
